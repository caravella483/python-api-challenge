# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
Analysis:
1. Weather becomes warmer as we approach the equater. From the plot, the northern hemispher seems to be slightly warmer. 
2. There is not much relationship between latitude and wind speed.
3. There is not much relationship between latitude and cloudiness.
4. There is not much relationship between latitude and humidity.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.weather_api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Wewak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=wewak
# Processing Record 2 | Amberley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=amberley
# Processing Record 3 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=torbay
# Processing Record 4 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tasiilaq
# Processing Record 5 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kenai
# Processing Record 6 | Awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=awjilah
# Processing Record 7 | Odessa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=odessa
# Processing Record 8 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kruisfontein
# Processing Record 9 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hamilton
# City not found. Skipping...
# Processing Record 10 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=port%20elizabeth
# Processing Record 11 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hilo
# Processing Record 12 | Stavanger
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=stavanger
# Processing Record 13 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=busselton
# Processing Record 14 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ushuaia
# Processing Record 15 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=albany
# Processing Record 16 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sao%20filipe
# Processing Record 17 | Ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ranong
# Processing Record 18 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=port%20blair
# Processing Record 19 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vaini
# Processing Record 20 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=rikitea
# Processing Record 21 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kapaa
# Processing Record 22 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mar%20del%20plata
# Processing Record 23 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=jamestown
# Processing Record 24 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saint-philippe
# Processing Record 25 | Ebebiyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ebebiyin
# Processing Record 26 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=victoria
# City not found. Skipping...
# Processing Record 27 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=makakilo%20city
# Processing Record 28 | Kajaani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kajaani
# Processing Record 29 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mogadishu
# Processing Record 30 | Hohr-Grenzhausen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hohr-grenzhausen
# Processing Record 31 | Cravo Norte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cravo%20norte
# Processing Record 32 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bredasdorp
# Processing Record 33 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=almaznyy
# Processing Record 34 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=port%20alfred
# Processing Record 35 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=faanui
# Processing Record 36 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mahebourg
# Processing Record 37 | Ventspils
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ventspils
# Processing Record 38 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=chokurdakh
# Processing Record 39 | Aguimes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=aguimes
# Processing Record 40 | Brockville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=brockville
# Processing Record 41 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=iqaluit
# Processing Record 42 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=punta%20arenas
# Processing Record 43 | Latung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=latung
# City not found. Skipping...
# Processing Record 44 | Joplin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=joplin
# Processing Record 45 | Menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=menongue
# Processing Record 46 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dukat
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 | Karaton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=karaton
# Processing Record 48 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=castro
# Processing Record 49 | Charlottetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=charlottetown
# Processing Record 50 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=north%20bend
# Processing Record 51 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=fortuna
# Processing Record 52 | Khunzakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=khunzakh
# Processing Record 53 | Ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ayr
# Processing Record 54 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=severo-kurilsk
# Processing Record 55 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=yellowknife
# Processing Record 56 | Iturama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=iturama
# Processing Record 57 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kodinsk
# Processing Record 58 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=flinders
# Processing Record 59 | Rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=rovaniemi
# Processing Record 60 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=qaanaaq
# Processing Record 61 | Barranquilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=barranquilla
# Processing Record 62 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=marawi
# Processing Record 63 | Palaikastron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=palaikastron
# Processing Record 64 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lompoc
# Processing Record 65 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=moron
# Processing Record 66 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saskylakh
# Processing Record 67 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ponta%20do%20sol
# Processing Record 68 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=taoudenni
# Processing Record 69 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nanortalik
# Processing Record 70 | Sfantu Gheorghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sfantu%20gheorghe
# Processing Record 71 | Severodvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=severodvinsk
# Processing Record 72 | Birin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=birin
# Processing Record 73 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=umm%20kaddadah
# Processing Record 74 | Toppenish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=toppenish
# Processing Record 75 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=yar-sale
# Processing Record 76 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=atuona
# Processing Record 77 | Caohai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=caohai
# Processing Record 78 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hermanus
# City not found. Skipping...
# Processing Record 79 | Vung Tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vung%20tau
# Processing Record 80 | Ruwi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ruwi
# Processing Record 81 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=upernavik
# Processing Record 82 | Simoes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=simoes
# Processing Record 83 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=namatanai
# Processing Record 84 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mataura
# Processing Record 85 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=zhangye
# Processing Record 86 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=chuy
# Processing Record 87 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=khatanga
# Processing Record 88 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=arraial%20do%20cabo
# Processing Record 89 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=narsaq
# Processing Record 90 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bluff
# Processing Record 91 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bethel
# City not found. Skipping...
# Processing Record 92 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=coahuayana
# Processing Record 93 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=puerto%20ayora
# Processing Record 94 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vao
# Processing Record 95 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kumluca
# Processing Record 96 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hobart
# Processing Record 97 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kaitangata
# Processing Record 98 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=avarua
# City not found. Skipping...
# Processing Record 99 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=georgetown
# Processing Record 100 | Ghanzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ghanzi
# Processing Record 101 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sitka
# Processing Record 102 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=san%20cristobal
# Processing Record 103 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=baykit
# Processing Record 104 | Puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=puri
# Processing Record 105 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=new%20norfolk
# City not found. Skipping...
# Processing Record 106 | Ibiruba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ibiruba
# Processing Record 107 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=carnarvon
# Processing Record 108 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=birao
# Processing Record 109 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=te%20anau
# Processing Record 110 | Cochrane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cochrane
# Processing Record 111 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saldanha
# Processing Record 112 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vila%20velha
# Processing Record 113 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=yulara
# Processing Record 114 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ambilobe
# Processing Record 115 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bara
# Processing Record 116 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kodiak
# Processing Record 117 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=norman%20wells
# Processing Record 118 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=arlit
# Processing Record 119 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=havre-saint-pierre
# Processing Record 120 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sinnamary
# Processing Record 121 | Kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kokopo
# Processing Record 122 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kavaratti
# Processing Record 123 | Peace River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=peace%20river
# Processing Record 124 | Whitecourt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=whitecourt
# Processing Record 125 | Turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=turayf
# Processing Record 126 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hay%20river
# City not found. Skipping...
# Processing Record 127 | Tevriz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tevriz
# Processing Record 128 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=clyde%20river
# Processing Record 129 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=buraydah
# Processing Record 130 | Ninghai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ninghai
# Processing Record 131 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cape%20town
# Processing Record 132 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nouakchott
# Processing Record 133 | Puerto del Rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=puerto%20del%20rosario
# Processing Record 134 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lazaro%20cardenas
# City not found. Skipping...
# Processing Record 135 | Santa Cecilia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=santa%20cecilia
# Processing Record 136 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=la%20ronge
# Processing Record 137 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=alofi
# Processing Record 138 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=abu%20dhabi
# Processing Record 139 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=agadez
# Processing Record 140 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lagoa
# Processing Record 141 | Naryan-Mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=naryan-mar
# Processing Record 142 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cidreira
# Processing Record 143 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=broome
# Processing Record 144 | Kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kenora
# Processing Record 145 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=barrow
# City not found. Skipping...
# Processing Record 146 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hithadhoo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 147 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=batagay-alyta
# City not found. Skipping...
# Processing Record 148 | Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=isla%20mujeres
# Processing Record 149 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hasaki
# City not found. Skipping...
# Processing Record 150 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=touros
# Processing Record 151 | Shinpokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=shinpokh
# Processing Record 152 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sobolevo
# Processing Record 153 | Mombasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mombasa
# Processing Record 154 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=anadyr
# Processing Record 155 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dikson
# Processing Record 156 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saint%20george
# City not found. Skipping...
# Processing Record 157 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=luderitz
# Processing Record 158 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=gat
# Processing Record 159 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mount%20isa
# Processing Record 160 | Ust-Ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ust-ishim
# Processing Record 161 | Iki-Burul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=iki-burul
# Processing Record 162 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=aquiraz
# Processing Record 163 | Tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tevaitoa
# Processing Record 164 | Sao Raimundo das Mangabeiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sao%20raimundo%20das%20mangabeiras
# City not found. Skipping...
# Processing Record 165 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=faya
# Processing Record 166 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=san%20patricio
# Processing Record 167 | Muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=muyezerskiy
# Processing Record 168 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=itoman
# Processing Record 169 | Vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vila
# Processing Record 170 | Butag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=butag
# City not found. Skipping...
# Processing Record 171 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=port%20macquarie
# Processing Record 172 | Rudsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=rudsar
# Processing Record 173 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=shimoda
# Processing Record 174 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mehamn
# Processing Record 175 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bubaque
# Processing Record 176 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=salinopolis
# Processing Record 177 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ahuimanu
# Processing Record 178 | At-Bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=at-bashi
# Processing Record 179 | Dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dauphin
# Processing Record 180 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mitsamiouli
# Processing Record 181 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=talnakh
# Processing Record 182 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=geraldton
# Processing Record 183 | Pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pringsewu
# Processing Record 184 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=broken%20hill
# Processing Record 185 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=margate
# Processing Record 186 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kununurra
# City not found. Skipping...
# Processing Record 187 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=praia
# Processing Record 188 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ahipara
# Processing Record 189 | Petropavl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=petropavl
# Processing Record 190 | Villa Carlos Paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=villa%20carlos%20paz
# Processing Record 191 | Oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=oranjestad
# Processing Record 192 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=camacha
# Processing Record 193 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=klaksvik
# Processing Record 194 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=fort%20nelson
# City not found. Skipping...
# Processing Record 195 | Gboko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=gboko
# Processing Record 196 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nikolskoye
# Processing Record 197 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=east%20london
# Processing Record 198 | Sol-Iletsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sol-iletsk
# Processing Record 199 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ostrovnoy
# Processing Record 200 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=butaritari
# Processing Record 201 | Florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=florianopolis
# Processing Record 202 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=shenjiamen
# Processing Record 203 | Grenada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=grenada
# Processing Record 204 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lebu
# Processing Record 205 | Tucurui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tucurui
# Processing Record 206 | Cacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cacu
# City not found. Skipping...
# Processing Record 207 | Kerikeri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kerikeri
# Processing Record 208 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hofn
# Processing Record 209 | Garden City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=garden%20city
# Processing Record 210 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=carutapera
# Processing Record 211 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vestmannaeyjar
# Processing Record 212 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=boyolangu
# Processing Record 213 | Anchorage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=anchorage
# Processing Record 214 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tuktoyaktuk
# Processing Record 215 | Narrabri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=narrabri
# Processing Record 216 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=komsomolskiy
# Processing Record 217 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=shingu
# Processing Record 218 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sorland
# Processing Record 219 | Tanhacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tanhacu
# Processing Record 220 | Manicore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=manicore
# Processing Record 221 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mao
# City not found. Skipping...
# Processing Record 222 | Jhajjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=jhajjar
# Processing Record 223 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=banda%20aceh
# City not found. Skipping...
# Processing Record 224 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=alice%20springs
# Processing Record 225 | Nesbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nesbyen
# Processing Record 226 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tual
# Processing Record 227 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ixtapa
# Processing Record 228 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=deputatskiy
# Processing Record 229 | Najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=najran
# Processing Record 230 | Monte Alegre de Minas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=monte%20alegre%20de%20minas
# Processing Record 231 | Vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vilyuysk
# Processing Record 232 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=buala
# Processing Record 233 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mahibadhoo
# Processing Record 234 | Gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=gubkinskiy
# Processing Record 235 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=solnechnyy
# Processing Record 236 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=martapura
# Processing Record 237 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=rawson
# Processing Record 238 | Lae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lae
# Processing Record 239 | Lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lima
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 240 | Tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tarakan
# Processing Record 241 | Muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=muroto
# Processing Record 242 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=byron%20bay
# Processing Record 243 | Monki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=monki
# Processing Record 244 | Baikunthpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=baikunthpur
# Processing Record 245 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=isangel
# Processing Record 246 | Haikou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=haikou
# Processing Record 247 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=itarema
# Processing Record 248 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=codrington
# Processing Record 249 | Volksrust
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=volksrust
# Processing Record 250 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=elizabeth%20city
# City not found. Skipping...
# Processing Record 251 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=coquimbo
# Processing Record 252 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mount%20gambier
# Processing Record 253 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=oranjemund
# Processing Record 254 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=acapulco
# Processing Record 255 | Sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sibu
# City not found. Skipping...
# Processing Record 256 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kysyl-syr
# Processing Record 257 | Aracataca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=aracataca
# Processing Record 258 | Filingue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=filingue
# Processing Record 259 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=caravelas
# Processing Record 260 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=beloha
# Processing Record 261 | Tucumcari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tucumcari
# Processing Record 262 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kaeo
# Processing Record 263 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=walvis%20bay
# City not found. Skipping...
# Processing Record 264 | Rongcheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=rongcheng
# Processing Record 265 | Ust-Kut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ust-kut
# City not found. Skipping...
# Processing Record 266 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ilulissat
# City not found. Skipping...
# Processing Record 267 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tiksi
# Processing Record 268 | Kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kautokeino
# Processing Record 269 | Lodwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lodwar
# Processing Record 270 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=homer
# City not found. Skipping...
# Processing Record 271 | Nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nurota
# Processing Record 272 | Marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=marystown
# Processing Record 273 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=constitucion
# Processing Record 274 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hobyo
# Processing Record 275 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=salinas
# Processing Record 276 | Chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=chimbote
# Processing Record 277 | Den Helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=den%20helder
# Processing Record 278 | Costa Rica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=costa%20rica
# Processing Record 279 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=port%20lincoln
# Processing Record 280 | Ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ilhabela
# Processing Record 281 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=matagami
# Processing Record 282 | California City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=california%20city
# Processing Record 283 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=samarai
# Processing Record 284 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=esperance
# Processing Record 285 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=souillac
# City not found. Skipping...
# Processing Record 286 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kiunga
# Processing Record 287 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=chicama
# Processing Record 288 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=airai
# Processing Record 289 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mahajanga
# Processing Record 290 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pevek
# Processing Record 291 | La Rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=la%20rioja
# Processing Record 292 | Kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kawalu
# Processing Record 293 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sungairaya
# Processing Record 294 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=padang
# Processing Record 295 | Amga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=amga
# Processing Record 296 | Balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=balkanabat
# Processing Record 297 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=adrar
# City not found. Skipping...
# Processing Record 298 | Nguruka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nguruka
# Processing Record 299 | Khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=khash
# Processing Record 300 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dunedin
# Processing Record 301 | Killybegs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=killybegs
# Processing Record 302 | Vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vanavara
# Processing Record 303 | Bezhetsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bezhetsk
# Processing Record 304 | Hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hun
# Processing Record 305 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pangnirtung
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 306 | Pucallpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pucallpa
# Processing Record 307 | Sar-e Pul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sar-e%20pul
# Processing Record 308 | Great Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=great%20falls
# Processing Record 309 | Krasnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=krasnoye
# Processing Record 310 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=labuhan
# Processing Record 311 | Stephenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=stephenville
# Processing Record 312 | Bulawayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bulawayo
# Processing Record 313 | Novaya Igirma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=novaya%20igirma
# Processing Record 314 | Lerici
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lerici
# City not found. Skipping...
# Processing Record 315 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cabo%20san%20lucas
# City not found. Skipping...
# Processing Record 316 | Zhenlai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=zhenlai
# Processing Record 317 | Oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=oudtshoorn
# Processing Record 318 | Dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dawlatabad
# Processing Record 319 | Markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=markova
# Processing Record 320 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kudahuvadhoo
# Processing Record 321 | Nkoteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nkoteng
# Processing Record 322 | Ewa Beach
# ...
# Processing Record 424 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saint-augustin
# Processing Record 425 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=eyl
# Processing Record 426 | Madera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=madera
# Processing Record 427 | Kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kuytun
# Processing Record 428 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=batemans%20bay
# Processing Record 429 | Ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ola
# Processing Record 430 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=riyadh
# Processing Record 431 | Sancti Spiritus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sancti%20spiritus
# Processing Record 432 | Springdale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=springdale
# Processing Record 433 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=inhambane
# Processing Record 434 | Iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=iskateley
# Processing Record 435 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=grand%20gaube
# Processing Record 436 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=gamba
# Processing Record 437 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tateyama
# Processing Record 438 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vostok
# Processing Record 439 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=axim
# Processing Record 440 | Drumheller
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=drumheller
# Processing Record 441 | Amilly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=amilly
# Processing Record 442 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=egvekinot
# Processing Record 443 | Ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ginda
# Processing Record 444 | Pasighat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pasighat
# Processing Record 445 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ulladulla
# Processing Record 446 | Tahoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tahoua
# Processing Record 447 | Balsas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=balsas
# Processing Record 448 | Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=omboue
# Processing Record 449 | Phan Thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=phan%20thiet
# Processing Record 450 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=raudeberg
# Processing Record 451 | Otukpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=otukpo
# Processing Record 452 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=christchurch
# Processing Record 453 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saint%20anthony
# Processing Record 454 | Buta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=buta
# Processing Record 455 | Ellisras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ellisras
# Processing Record 456 | Janakpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=janakpur
# Processing Record 457 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=marsh%20harbour
# Processing Record 458 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=fukue
# City not found. Skipping...
# Processing Record 459 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=emerald
# Processing Record 460 | Abnub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=abnub
# Processing Record 461 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lavrentiya
# Processing Record 462 | Kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kamaishi
# Processing Record 463 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hovd
# City not found. Skipping...
# Processing Record 464 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=vardo
# Processing Record 465 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=saint-pierre
# Processing Record 466 | Bowling Green
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bowling%20green
# Processing Record 467 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=westport
# Processing Record 468 | Bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bam
# Processing Record 469 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=acajutla
# Processing Record 470 | Japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=japura
# Processing Record 471 | Hrob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hrob
# Processing Record 472 | Khandbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=khandbari
# Processing Record 473 | Lashio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=lashio
# Processing Record 474 | Menfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=menfi
# Processing Record 475 | Dhanaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dhanaula
# Processing Record 476 | Pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pontianak
# Processing Record 477 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nouadhibou
# Processing Record 478 | Hadgaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=hadgaon
# City not found. Skipping...
# Processing Record 479 | Arcachon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=arcachon
# Processing Record 480 | Mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=mantua
# Processing Record 481 | Kamiiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kamiiso
# Processing Record 482 | Sovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sovetskiy
# Processing Record 483 | Ribeira Brava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ribeira%20brava
# Processing Record 484 | Bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=bulgan
# Processing Record 485 | Andros Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=andros%20town
# City not found. Skipping...
# Processing Record 486 | Garmsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=garmsar
# Processing Record 487 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pisco
# City not found. Skipping...
# Processing Record 488 | Ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ajdabiya
# Processing Record 489 | Nauta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nauta
# Processing Record 490 | Beni Mazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=beni%20mazar
# Processing Record 491 | Urusha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=urusha
# Processing Record 492 | Tekeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tekeli
# Processing Record 493 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=cayenne
# Processing Record 494 | Algiers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=algiers
# Processing Record 495 | Pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pundaguitan
# Processing Record 496 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=udachnyy
# Processing Record 497 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=zhigansk
# Processing Record 498 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=beringovskiy
# Processing Record 499 | Reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=reconquista
# Processing Record 500 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=quatre%20cocos
# Processing Record 501 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=imbituba
# Processing Record 502 | Teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=teknaf
# Processing Record 503 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=aykhal
# Processing Record 504 | Csengod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=csengod
# Processing Record 505 | Elliot Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=elliot%20lake
# Processing Record 506 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kupang
# Processing Record 507 | Sosva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sosva
# Processing Record 508 | Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tabou
# Processing Record 509 | Dumas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dumas
# Processing Record 510 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sechura
# Processing Record 511 | Tawau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tawau
# Processing Record 512 | Gangakher
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=gangakher
# Processing Record 513 | San Eugenio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=san%20eugenio
# Processing Record 514 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=dali
# City not found. Skipping...
# Processing Record 515 | Kalaleh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kalaleh
# Processing Record 516 | Pampierstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=pampierstad
# Processing Record 517 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=fare
# Processing Record 518 | Tucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tucupita
# Processing Record 519 | Kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=kulhudhuffushi
# Processing Record 520 | Ludza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ludza
# City not found. Skipping...
# Processing Record 521 | La Union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=la%20union
# City not found. Skipping...
# Processing Record 522 | Sangmelima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sangmelima
# Processing Record 523 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=muros
# Processing Record 524 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=san%20quintin
# Processing Record 525 | Razdolnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=razdolnoye
# Processing Record 526 | Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=havelock
# Processing Record 527 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=sao%20joao%20da%20barra
# Processing Record 528 | Ust-Tarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=ust-tarka
# Processing Record 529 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=nyurba
# City not found. Skipping...
# Processing Record 530 | Tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=tahe
# Processing Record 531 | North Platte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=006aef7c08f36e6c507190f501b16bc6&q=north%20platte

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          531
# Cloudiness    531
# Country       531
# Date          531
# Humidity      531
# Lat           531
# Lng           531
# Max Temp      531
# Wind Speed    531
# dtype: int64

# %%
# Output File (CSV)
#output_data_file = "output_data/cities.csv"
# Save data frame to CSV
weather_data.to_csv("../output_data/weather_data.csv")

# Display data frame head 
weather_data.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Wewak          39      PG  1577896020        87  -3.55  143.63
# 1  Amberley         100      NZ  1577896021       100 -43.15  172.73
# 2    Torbay          90      CA  1577896022        92  47.66  -52.73
# 3  Tasiilaq           0      GL  1577896023        66  65.61  -37.64
# 4     Kenai          75      US  1577896024        71  60.55 -151.26
#
#    Max Temp  Wind Speed
# 0     78.42        9.42
# 1     59.00        2.24
# 2     33.01       34.45
# 3     12.20       28.86
# 4     10.99       19.46

# %%
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  severo-kurilsk          92      RU  1534988024        93  50.68  156.12
# 1          darhan           8      MN  1534988024        71  49.49  105.92
# 2         tarakan          48      ID  1534988024       100   3.30  117.63
# 3    komsomolskiy          48      RU  1534987754        72  67.55   63.78
# 4        souillac           0      FR  1534986000        73  45.60   -0.60
#
#    Max Temp  Wind Speed
# 0     54.27        2.73
# 1     72.81        8.55
# 2     80.10        4.41
# 3     54.46       15.46
# 4     71.60        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
